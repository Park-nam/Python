# %%
import pymysql
import pandas as pd

# %%
conn = pymysql.connect(host = 'localhost',user='root',
                       password='951824',db='sakila', charset='utf8')
curs = conn.cursor()

# %%
pd.read_sql('select * from actor_info',conn)
# Out:
#      actor_id first_name     last_name  \
# 0           1   PENELOPE       GUINESS
# 1           2       NICK      WAHLBERG
# 2           3         ED         CHASE
# 3           4   JENNIFER         DAVIS
# 4           5     JOHNNY  LOLLOBRIGIDA
# ..        ...        ...           ...
# 195       196       BELA        WALKEN
# 196       197      REESE          WEST
# 197       198       MARY        KEITEL
# 198       199      JULIA       FAWCETT
# 199       200      THORA        TEMPLE
#
#                                              film_info
# 0    Animation: ANACONDA CONFESSIONS; Children: LAN...
# 1    Action: BULL SHAWSHANK; Animation: FIGHT JAWBR...
# 2    Action: CADDYSHACK JEDI, FORREST SONS; Classic...
# 3    Action: BAREFOOT MANCHURIAN; Animation: ANACON...
# 4    Action: AMADEUS HOLY, GRAIL FRANKENSTEIN, RING...
# ..                                                 ...
# 195  Action: FANTASY TROOPERS; Animation: LUKE MUMM...
# ...

# %%
pd.read_sql('select actor_id from actor_info where actor_id = 4',conn)
# Out:
#    actor_id
# 0         4
